# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import tensorflow as tf
import keras as K
from keras_applications import vgg16
from keras.utils import np_utils
import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
# DNN model

def DNN_Model(dataset=None,label=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = dataset[use_features].shape[0]
    input_dim = dataset[use_features].shape[1]
    
    Y = np_utils.to_categorical(dataset[label],num_classes=3)
    x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 130
    max_epochs = 10
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
# plot the learning curves
# use history function to collect losses and accuracies in each epoch

def plot_learning_curves(history):

    epochs = range(len(history.history['accuracy']))
    plt.figure()
    plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
    plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    output_dir = "output/figures"
    plt.savefig('{}/model_accuracy.jpg'.format(output_dir))

    plt.figure()
    plt.plot(epochs,history.history['loss'],'b',label='Training loss')
    plt.plot(epochs,history.history['val_loss'],'r',label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('{}/model_loss.jpg'.format(output_dir))
    
    return

# %%
# plot the learning curves
# use history function to collect losses and accuracies in each epoch

def plot_learning_curves(history):

    epochs = range(len(history.history['accuracy']))
    plt.figure()
    plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
    plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    output_dir = "output/figures"
    plt.savefig('{}/model_accuracy.jpg'.format(output_dir))

    plt.figure()
    plt.plot(epochs,history.history['loss'],'b',label='Training loss')
    plt.plot(epochs,history.history['val_loss'],'r',label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('{}/model_loss.jpg'.format(output_dir))
    
    return

# %%
# run the model

dataset = pd.read_csv('input/dataset_merged_2d.csv')[:5000]

del_feature = ['link','label']
use_features = [i for i in dataset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(dataset=dataset,label="label",use_features=use_features,
                  categorical_feats=None, n_class=3)
loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 17:20:13.717723
# Start training
#
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/50
# 3500/3500 [==============================] - 1s 227us/step - loss: 3.7919 - accuracy: 0.5077 - val_loss: 2.4508 - val_accuracy: 0.7260
# Epoch 2/50
# 3500/3500 [==============================] - 0s 27us/step - loss: 1.9202 - accuracy: 0.7411 - val_loss: 1.5041 - val_accuracy: 0.7567
# Epoch 3/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 1.2535 - accuracy: 0.7677 - val_loss: 1.0720 - val_accuracy: 0.7653
# Epoch 4/50
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.9514 - accuracy: 0.7726 - val_loss: 0.8820 - val_accuracy: 0.7687
# Epoch 5/50
# 3500/3500 [==============================] - 0s 27us/step - loss: 0.8236 - accuracy: 0.7723 - val_loss: 0.8067 - val_accuracy: 0.7753
# Epoch 6/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.7681 - accuracy: 0.7823 - val_loss: 0.7575 - val_accuracy: 0.7800
# Epoch 7/50
# 3500/3500 [==============================] - 0s 27us/step - loss: 0.7248 - accuracy: 0.7926 - val_loss: 0.7136 - val_accuracy: 0.7867
# Epoch 8/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.6852 - accuracy: 0.7966 - val_loss: 0.6705 - val_accuracy: 0.7907
# Epoch 9/50
# 3500/3500 [==============================] - 0s 27us/step - loss: 0.6519 - accuracy: 0.7997 - val_loss: 0.6363 - val_accuracy: 0.7927
# Epoch 10/50
# 3500/3500 [==============================] - 0s 32us/step - loss: 0.6253 - accuracy: 0.8029 - val_loss: 0.6080 - val_accuracy: 0.7960
# Epoch 11/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.6012 - accuracy: 0.8029 - val_loss: 0.5843 - val_accuracy: 0.7993
# Epoch 12/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.5791 - accuracy: 0.8051 - val_loss: 0.5631 - val_accuracy: 0.8007
# Epoch 13/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.5616 - accuracy: 0.8051 - val_loss: 0.5451 - val_accuracy: 0.8047
# Epoch 14/50
# 3500/3500 [==============================] - 0s 26us/step - loss: 0.5478 - accuracy: 0.8060 - val_loss: 0.5331 - val_accuracy: 0.8033
# Epoch 15/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.5329 - accuracy: 0.8077 - val_loss: 0.5200 - val_accuracy: 0.8047
# Epoch 16/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.5224 - accuracy: 0.8080 - val_loss: 0.5099 - val_accuracy: 0.8013
# 3500/3500 [==============================] - 0s 34us/step - loss: 0.4590 - accuracy: 0.8131 - val_loss: 0.4538 - val_accuracy: 0.8213
# Epoch 35/50
# 3500/3500 [==============================] - 0s 34us/step - loss: 0.4556 - accuracy: 0.8140 - val_loss: 0.4511 - val_accuracy: 0.8213
# Epoch 36/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.4543 - accuracy: 0.8146 - val_loss: 0.4510 - val_accuracy: 0.8240
# Epoch 37/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.4534 - accuracy: 0.8149 - val_loss: 0.4485 - val_accuracy: 0.8233
# Epoch 38/50
# 3500/3500 [==============================] - 0s 20us/step - loss: 0.4527 - accuracy: 0.8151 - val_loss: 0.4475 - val_accuracy: 0.8227
# Epoch 39/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.4515 - accuracy: 0.8169 - val_loss: 0.4486 - val_accuracy: 0.8247
# Epoch 40/50
# 3500/3500 [==============================] - 0s 19us/step - loss: 0.4508 - accuracy: 0.8157 - val_loss: 0.4461 - val_accuracy: 0.8260
# Epoch 41/50
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.4495 - accuracy: 0.8157 - val_loss: 0.4477 - val_accuracy: 0.8233
# Epoch 42/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4498 - accuracy: 0.8169 - val_loss: 0.4454 - val_accuracy: 0.8220
# Epoch 43/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4505 - accuracy: 0.8194 - val_loss: 0.4438 - val_accuracy: 0.8247
# Epoch 44/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4511 - accuracy: 0.8206 - val_loss: 0.4432 - val_accuracy: 0.8240
# Epoch 45/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.4490 - accuracy: 0.8189 - val_loss: 0.4435 - val_accuracy: 0.8207
# Epoch 46/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.4465 - accuracy: 0.8189 - val_loss: 0.4432 - val_accuracy: 0.8200
# Epoch 47/50
# 3500/3500 [==============================] - 0s 31us/step - loss: 0.4462 - accuracy: 0.8214 - val_loss: 0.4414 - val_accuracy: 0.8240
# Epoch 48/50
# 3500/3500 [==============================] - 0s 19us/step - loss: 0.4461 - accuracy: 0.8186 - val_loss: 0.4458 - val_accuracy: 0.8213
# Epoch 49/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.4455 - accuracy: 0.8180 - val_loss: 0.4406 - val_accuracy: 0.8253
# Epoch 50/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.4421 - accuracy: 0.8231 - val_loss: 0.4412 - val_accuracy: 0.8213
# Training completed
#
# [0.4412105083465576, 0.8213333487510681]
# Loss on test set =  0.4412105083465576
# Accuracy on test set =  0.8213333487510681
# 2020-12-14 17:20:20.888157
