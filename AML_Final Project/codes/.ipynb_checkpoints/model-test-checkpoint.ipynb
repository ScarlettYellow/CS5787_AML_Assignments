# %% [markdown]
# # DNN model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import tensorflow as tf
import keras as K
from keras_applications import vgg16
from keras.utils import np_utils
import datetime

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/scarlett/opt/anaconda3/envs/zopencv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [raw]
# ## Experiment 1
#
# - Dataset: 5000 pieces of data
# - max_epochs: 20
# - batch_size: 130

# %%
# DNN model

def DNN_Model(trainset=None,label=None,testset=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = trainset[use_features].shape[0]
    input_dim = trainset[use_features].shape[1]
    
    #Y = np_utils.to_categorical(trainset[label],num_classes=3)
    
    x_train = trainset[use_features]
    y_train = np_utils.to_categorical(trainset[label],num_classes=3)
    x_test = testset[use_features]
    y_test = np_utils.to_categorical(testset[label],num_classes=3)
    
    #x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        #train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 130
    max_epochs = 20
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
# plot the learning curves
# use history function to collect losses and accuracies in each epoch

def plot_learning_curves(history):

    epochs = range(len(history.history['accuracy']))
    plt.figure()
    plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
    plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    output_dir = "output/figures"
    plt.savefig('{}/model_accuracy.jpg'.format(output_dir))

    plt.figure()
    plt.plot(epochs,history.history['loss'],'b',label='Training loss')
    plt.plot(epochs,history.history['val_loss'],'r',label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig('{}/model_loss.jpg'.format(output_dir))
    
    return

# %%
trainset = pd.read_csv('input/dataset_merged_2d.csv')[:10000]
testset = pd.read_csv('input/testset_20200701.csv')[:3000]

del_feature = ['link','label']
use_features = [i for i in trainset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(trainset=trainset,label="label",testset=testset,
                use_features=use_features,
                categorical_feats=None, n_class=3)

loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 18:42:39.653194
# Start training
#
# Train on 10000 samples, validate on 3000 samples
# Epoch 1/20
# Epoch 20/20
# 10000/10000 [==============================] - 0s 26us/step - loss: 0.4340 - accuracy: 0.8281 - val_loss: 0.4198 - val_accuracy: 0.8393
# Training completed
#
# [0.4198396532734235, 0.8393333554267883]
# Loss on test set =  0.4198396532734235
# Accuracy on test set =  0.8393333554267883
# 2020-12-14 18:42:45.040962

# %% [raw]
# ## Experiment 2
#
# - Dataset: 5000 pieces of data
# - max_epochs: 50
# - batch_size: 150

# %%
# DNN model

def DNN_Model(dataset=None,label=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = dataset[use_features].shape[0]
    input_dim = dataset[use_features].shape[1]
    
    Y = np_utils.to_categorical(dataset[label],num_classes=3)
    x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 150
    max_epochs = 50
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
dataset = pd.read_csv('input/dataset_merged_2d.csv')[:5000]

del_feature = ['link','label']
use_features = [i for i in dataset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(dataset=dataset,label="label",
                use_features=use_features,
                categorical_feats=None, n_class=3)

loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 17:42:27.473156
# Start training
#
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/50
# 3500/3500 [==============================] - 1s 193us/step - loss: 3.7655 - accuracy: 0.5117 - val_loss: 2.4122 - val_accuracy: 0.7287
# Epoch 2/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 1.9192 - accuracy: 0.7414 - val_loss: 1.5037 - val_accuracy: 0.7553
# Epoch 3/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 1.2464 - accuracy: 0.7709 - val_loss: 1.0742 - val_accuracy: 0.7687
# Epoch 4/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.9439 - accuracy: 0.7740 - val_loss: 0.8783 - val_accuracy: 0.7673
# Epoch 5/50
# 3500/3500 [==============================] - 0s 18us/step - loss: 0.8181 - accuracy: 0.7769 - val_loss: 0.7987 - val_accuracy: 0.7767
# Epoch 6/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.7599 - accuracy: 0.7846 - val_loss: 0.7490 - val_accuracy: 0.7800
# Epoch 7/50
# 3500/3500 [==============================] - 0s 31us/step - loss: 0
50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.4626 - accuracy: 0.8123 - val_loss: 0.4602 - val_accuracy: 0.8160
# Epoch 32/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4617 - accuracy: 0.8143 - val_loss: 0.4585 - val_accuracy: 0.8160
# Epoch 33/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.4594 - accuracy: 0.8149 - val_loss: 0.4544 - val_accuracy: 0.8227
# Epoch 34/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.4579 - accuracy: 0.8143 - val_loss: 0.4563 - val_accuracy: 0.8187
# Epoch 35/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4581 - accuracy: 0.8140 - val_loss: 0.4539 - val_accuracy: 0.8187
# Epoch 36/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.4559 - accuracy: 0.8146 - val_loss: 0.4518 - val_accuracy: 0.8213
# Epoch 37/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.4563 - accuracy: 0.8149 - val_loss: 0.4503 - val_accuracy: 0.8233
# Epoch 38/50
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.4544 - accuracy: 0.8151 - val_loss: 0.4493 - val_accuracy: 0.8220
# Epoch 39/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.4536 - accuracy: 0.8146 - val_loss: 0.4483 - val_accuracy: 0.8227
# Epoch 40/50
# 3500/3500 [==============================] - 0s 20us/step - loss: 0.4519 - accuracy: 0.8163 - val_loss: 0.4477 - val_accuracy: 0.8227
# Epoch 41/50
# 3500/3500 [==============================] - 0s 19us/step - loss: 0.4511 - accuracy: 0.8169 - val_loss: 0.4476 - val_accuracy: 0.8247
# Epoch 42/50
# 3500/3500 [==============================] - 0s 19us/step - loss: 0.4502 - accuracy: 0.8171 - val_loss: 0.4461 - val_accuracy: 0.8240
# Epoch 43/50
# 3500/3500 [==============================] - 0s 20us/step - loss: 0.4506 - accuracy: 0.8166 - val_loss: 0.4452 - val_accuracy: 0.8227
# Epoch 44/50
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.4498 - accuracy: 0.8177 - val_loss: 0.4460 - val_accuracy: 0.8240
# Epoch 45/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.4481 - accuracy: 0.8154 - val_loss: 0.4449 - val_accuracy: 0.8227
# Epoch 46/50
# 3500/3500 [==============================] - 0s 22us/step - loss: 0.4487 - accuracy: 0.8163 - val_loss: 0.4448 - val_accuracy: 0.8220
# Epoch 47/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.4464 - accuracy: 0.8171 - val_loss: 0.4431 - val_accuracy: 0.8227
# Epoch 48/50
# 3500/3500 [==============================] - 0s 46us/step - loss: 0.4467 - accuracy: 0.8180 - val_loss: 0.4419 - val_accuracy: 0.8247
# Epoch 49/50
# 3500/3500 [==============================] - 0s 25us/step - loss: 0.4455 - accuracy: 0.8191 - val_loss: 0.4421 - val_accuracy: 0.8233
# Epoch 50/50
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.4450 - accuracy: 0.8206 - val_loss: 0.4408 - val_accuracy: 0.8233
# Training completed
#
# [0.4408203840255737, 0.8233333230018616]
# Loss on test set =  0.4408203840255737
# Accuracy on test set =  0.8233333230018616
# 2020-12-14 17:42:33.352205

# %% [raw]
# ## Experiment 3
#
# - Dataset: 5000 pieces of data
# - max_epochs: 100
# - batch_size: 200

# %%
# DNN model

def DNN_Model(dataset=None,label=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = dataset[use_features].shape[0]
    input_dim = dataset[use_features].shape[1]
    
    Y = np_utils.to_categorical(dataset[label],num_classes=3)
    x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 200
    max_epochs = 100
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
dataset = pd.read_csv('input/dataset_merged_2d.csv')[:5000]

del_feature = ['link','label']
use_features = [i for i in dataset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(dataset=dataset,label="label",
                use_features=use_features,
                categorical_feats=None, n_class=3)

loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 17:44:30.119313
# Start training
#
# Train on 3500 samples, validate on 1500 samples
# Epoch 1/100
# 3500/3500 [==============================] - 1s 272us/step - loss: 4.0981 - accuracy: 0.4374 - val_loss: 2.7255 - val_accuracy: 0.7220
# Epoch 2/100
# 3500/3500 [==============================] - 0s 18us/step - loss: 2.2628 - accuracy: 0.7277 - val_loss: 1.8342 - val_accuracy: 0.7427
# Epoch 3/100
# 3500/3500 [==============================] - 0s 21us/step - loss: 1.5410 - accuracy: 0.7589 - val_loss: 1.3134 - val_accuracy: 0.7647
# Epoch 4/100
# 3500/3500 [==============================] - 0s 19us/step - loss: 1.1450 - accuracy: 0.7714 - val_loss: 1.0309 - val_accuracy: 0.7687
# Epoch 5/100
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.9303 - accuracy: 0.7726 - val_loss: 0.8946 - val_accuracy: 0.7687
# Epoch 6/100
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.8336 - accuracy: 0.7769 - val_loss: 0.8230 - val_accuracy: 0.7727
# Epoch 7/100
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.7840 - accuracy: 0.7777 - val_loss: 0.7785 - val_accuracy: 0.7773
# Epoch 8/100
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.7468 - accuracy: 0.7871 - val_loss: 0.7385 - val_accuracy: 0.7827
# Epoch 9/100
# 3500/3500 [==============================] - 0s 23us/step - loss: 0.7114 - accuracy: 0.7951 - val_loss: 0.7009 - val_accuracy: 0.7900
# Epoch 10/100
# 3500/3500 [==============================] - 0s 24us/step - loss: 0.6793 - accuracy: 0.7983 - val_loss: 0.6682 - val_accuracy: 0.7893
# Epoch 11/100
# 3500/3500 [==============================] - 0s 21us/step - loss: 0.6532 - accuracy: 0.8003 - val_loss: 0.6416 - val_accuracy: 0.7940
# Epoch 12/100
# 3500/3500 [==============================] - 0s 17us/step - loss: 0.6304 - accuracy: 0.8014 - val_loss: 0.6171 - val_accuracy: 0.7927
# Epoch 13/100
# 3500/3500 [==============================] - 0s 18us/step - loss: 0.6102 - accuracy: 0.8037 - val_loss: 0.5968 - val_accuracy: 0.7960
# Epoch 14/100
# 3500/3500 [==============================] - 0s 15us/step - loss: 0.5922 - accuracy: 0.8046 - val_loss: 0.5782 - val_accuracy: 0.8007
# Epoch 15/100
# 3500/3500 [==============================] - 0s 18us/step - loss: 0.5761 - accuracy: 0.8054 - val_loss: 0.5627 - val_accuracy: 0.8007
# Epoch 16/100
# 3500/3500 [==============================] - 0s 19us/step - loss: 0
100
# 3500/3500 [==============================] - 0s 16us/step - loss: 0.4283 - accuracy: 0.8346 - val_loss: 0.4350 - val_accuracy: 0.8247
# Epoch 96/100
# 3500/3500 [==============================] - 0s 19us/step - loss: 0.4269 - accuracy: 0.8377 - val_loss: 0.4375 - val_accuracy: 0.8267
# Epoch 97/100
# 3500/3500 [==============================] - 0s 16us/step - loss: 0.4271 - accuracy: 0.8366 - val_loss: 0.4351 - val_accuracy: 0.8240
# Epoch 98/100
# 3500/3500 [==============================] - 0s 15us/step - loss: 0.4267 - accuracy: 0.8340 - val_loss: 0.4337 - val_accuracy: 0.8260
# Epoch 99/100
# 3500/3500 [==============================] - 0s 17us/step - loss: 0.4270 - accuracy: 0.8371 - val_loss: 0.4335 - val_accuracy: 0.8253
# Epoch 100/100
# 3500/3500 [==============================] - 0s 15us/step - loss: 0.4268 - accuracy: 0.8383 - val_loss: 0.4345 - val_accuracy: 0.8247
# Training completed
#
# [0.4345468739668528, 0.8246666789054871]
# Loss on test set =  0.4345468739668528
# Accuracy on test set =  0.8246666789054871
# 2020-12-14 17:44:38.928346

# %% [raw]
# ## Experiment 4
#
# - Dataset: all data
# - max_epochs: 100
# - batch_size: 1000

# %%
# DNN model

def DNN_Model(dataset=None,label=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = dataset[use_features].shape[0]
    input_dim = dataset[use_features].shape[1]
    
    Y = np_utils.to_categorical(dataset[label],num_classes=3)
    x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 1000
    max_epochs = 100
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
dataset = pd.read_csv('input/dataset_merged_2d.csv')

del_feature = ['link','label']
use_features = [i for i in dataset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(dataset=dataset,label="label",
                use_features=use_features,
                categorical_feats=None, n_class=3)

loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 17:47:11.670707
# Start training
#
# Train on 2866012 samples, validate on 1228292 samples
# Epoch 1/100
# 2866012/2866012 [==============================] - 28s 10us/step - loss: 0.4991 - accuracy: 0.8242 - val_loss: 0.4146 - val_accuracy: 0.8427
100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3848 - accuracy: 0.8516 - val_loss: 0.3852 - val_accuracy: 0.8510
# Epoch 47/100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3845 - accuracy: 0.8517 - val_loss: 0.3856 - val_accuracy: 0.8510
# Epoch 48/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3843 - accuracy: 0.8517 - val_loss: 0.3834 - val_accuracy: 0.8522
# Epoch 49/100
# 2866012/2866012 [==============================] - 18s 6us/step - loss: 0.3841 - accuracy: 0.8518 - val_loss: 0.3872 - val_accuracy: 0.8500
# Epoch 50/100
# 2866012/2866012 [==============================] - 18s 6us/step - loss: 0.3840 - accuracy: 0.8518 - val_loss: 0.3861 - val_accuracy: 0.8516
# Epoch 51/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3839 - accuracy: 0.8518 - val_loss: 0.3858 - val_accuracy: 0.8512
# Epoch 52/100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3838 - accuracy: 0.8518 - val_loss: 0.3828 - val_accuracy: 0.8520
# Epoch 53/100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3836 - accuracy: 0.8518 - val_loss: 0.3857 - val_accuracy: 0.8510
# Epoch 54/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3836 - accuracy: 0.8518 - val_loss: 0.3897 - val_accuracy: 0.8497
# Epoch 55/100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3835 - accuracy: 0.8517 - val_loss: 0.3968 - val_accuracy: 0.8472
# Epoch 56/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3835 - accuracy: 0.8517 - val_loss: 0.3820 - val_accuracy: 0.8521
# Epoch 57/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3833 - accuracy: 0.8519 - val_loss: 0.3836 - val_accuracy: 0.8517
# Epoch 58/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3833 - accuracy: 0.8518 - val_loss: 0.3834 - val_accuracy: 0.8514
# Epoch 59/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3831 - accuracy: 0.8519 - val_loss: 0.3840 - val_accuracy: 0.8508
# Epoch 60/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3830 - accuracy: 0.8518 - val_loss: 0.3852 - val_accuracy: 0.8520
# Epoch 61/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3830 - accuracy: 0.8517 - val_loss: 0.3827 - val_accuracy: 0.8515
# Epoch 62/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3827 - accuracy: 0.8517 - val_loss: 0.3945 - val_accuracy: 0.8463
# Epoch 63/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3828 - accuracy: 0.8516 - val_loss: 0.3816 - val_accuracy: 0.8520
# Epoch 64/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3827 - accuracy: 0.8518 - val_loss: 0.3835 - val_accuracy: 0.8509
# Epoch 65/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3826 - accuracy: 0.8517 - val_loss: 0.3898 - val_accuracy: 0.8483
# Epoch 66/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3826 - accuracy: 0.8518 - val_loss: 0.3845 - val_accuracy: 0.8510
# Epoch 67/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3826 - accuracy: 0.8517 - val_loss: 0.3846 - val_accuracy: 0.8508
# Epoch 68/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3826 - accuracy: 0.8516 - val_loss: 0.3837 - val_accuracy: 0.8505
# Epoch 69/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3826 - accuracy: 0.8517 - val_loss: 0.3822 - val_accuracy: 0.8522
# Epoch 70/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3824 - accuracy: 0.8518 - val_loss: 0.3939 - val_accuracy: 0.8493
# Epoch 71/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3825 - accuracy: 0.8517 - val_loss: 0.3823 - val_accuracy: 0.8511
# Epoch 72/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3824 - accuracy: 0.8517 - val_loss: 0.3851 - val_accuracy: 0.8505
# Epoch 73/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3824 - accuracy: 0.8517 - val_loss: 0.3825 - val_accuracy: 0.8520
# Epoch 74/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3823 - accuracy: 0.8516 - val_loss: 0.3887 - val_accuracy: 0.8516
# Epoch 75/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3824 - accuracy: 0.8518 - val_loss: 0.3815 - val_accuracy: 0.8518
# Epoch 76/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3823 - accuracy: 0.8518 - val_loss: 0.3819 - val_accuracy: 0.8520
# Epoch 77/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3823 - accuracy: 0.8518 - val_loss: 0.3812 - val_accuracy: 0.8520
# Epoch 78/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3811 - val_accuracy: 0.8521
# Epoch 79/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3848 - val_accuracy: 0.8520
# Epoch 80/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3828 - val_accuracy: 0.8513
# Epoch 81/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3810 - val_accuracy: 0.8521
# Epoch 82/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3823 - accuracy: 0.8517 - val_loss: 0.3842 - val_accuracy: 0.8516
# Epoch 83/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3813 - val_accuracy: 0.8516
# Epoch 84/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3821 - val_accuracy: 0.8517
# Epoch 85/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8518 - val_loss: 0.3808 - val_accuracy: 0.8522
# Epoch 86/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3820 - accuracy: 0.8517 - val_loss: 0.3815 - val_accuracy: 0.8519
# Epoch 87/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3822 - accuracy: 0.8517 - val_loss: 0.3849 - val_accuracy: 0.8501
# Epoch 88/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3821 - accuracy: 0.8518 - val_loss: 0.3823 - val_accuracy: 0.8515
# Epoch 89/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3820 - accuracy: 0.8519 - val_loss: 0.3823 - val_accuracy: 0.8516
# Epoch 90/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3820 - accuracy: 0.8519 - val_loss: 0.3852 - val_accuracy: 0.8495
# Epoch 91/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3821 - accuracy: 0.8517 - val_loss: 0.3825 - val_accuracy: 0.8509
# Epoch 92/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3820 - accuracy: 0.8519 - val_loss: 0.3815 - val_accuracy: 0.8520
# Epoch 93/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3820 - accuracy: 0.8520 - val_loss: 0.3841 - val_accuracy: 0.8521
# Epoch 94/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3819 - accuracy: 0.8519 - val_loss: 0.3824 - val_accuracy: 0.8525
# Epoch 95/100
# 2866012/2866012 [==============================] - 16s 5us/step - loss: 0.3820 - accuracy: 0.8519 - val_loss: 0.3820 - val_accuracy: 0.8519
# Epoch 96/100
# 2866012/2866012 [==============================] - 18s 6us/step - loss: 0.3820 - accuracy: 0.8519 - val_loss: 0.3810 - val_accuracy: 0.8523
# Epoch 97/100
# 2866012/2866012 [==============================] - 15s 5us/step - loss: 0.3819 - accuracy: 0.8519 - val_loss: 0.3846 - val_accuracy: 0.8504
# Epoch 98/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3819 - accuracy: 0.8519 - val_loss: 0.3917 - val_accuracy: 0.8478
# Epoch 99/100
# 2866012/2866012 [==============================] - 14s 5us/step - loss: 0.3819 - accuracy: 0.8520 - val_loss: 0.3808 - val_accuracy: 0.8517
# Epoch 100/100
# 2866012/2866012 [==============================] - 13s 5us/step - loss: 0.3819 - accuracy: 0.8520 - val_loss: 0.3815 - val_accuracy: 0.8518
# Training completed
#
# [0.38147613008778863, 0.8517917394638062]
# Loss on test set =  0.38147613008778863
# Accuracy on test set =  0.8517917394638062
# 2020-12-14 18:17:43.974659

# %% [raw]
# ## Experiment 5
#
# - Dataset: all data
# - max_epochs: 100
# - batch_size: 200

# %%
# DNN model

def DNN_Model(dataset=None,label=None,use_features=None,categorical_feats=None, n_class=3):
    input_length = dataset[use_features].shape[0]
    input_dim = dataset[use_features].shape[1]
    
    Y = np_utils.to_categorical(dataset[label],num_classes=3)
    x_train, x_test, y_train, y_test = train_test_split(dataset[use_features], Y,
                                                        train_size=0.7, test_size=0.3, random_state=0)
    
    # define the model 
    init = K.initializers.glorot_uniform(seed=1)
    simple_adam = K.optimizers.Adam(lr=0.001)
    model = K.models.Sequential()
    model.add(K.layers.Dense(units=5, input_shape=(input_dim,), kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=6, kernel_initializer=init, activation='relu'))
    model.add(K.layers.Dense(units=n_class, kernel_initializer=init, activation='softmax'))
    model.compile(loss="categorical_crossentropy",
                  optimizer=simple_adam,
                  #optimizer="rmsprop",
                  metrics=["accuracy"])

    # train the model
    b_size = 1000
    max_epochs = 100
    print ("Start training \n")
    
    history = model.fit(x_train, y_train, 
                        batch_size=b_size,
                        epochs=max_epochs,
                        shuffle=True,
                        validation_data=(x_test, y_test),
                        verbose=1)
    print ("Training completed \n")
    
    # evaluate the model performance
    # scores: includes val_loss and val_acc
    scores = model.evaluate(x_test, y_test, batch_size=b_size,verbose=0)
    print(scores)
    loss = scores[0]
    acc = scores[1]
    
    return loss,acc,history

# %%
dataset = pd.read_csv('input/dataset_merged_2d.csv')

del_feature = ['link','label']
use_features = [i for i in dataset.columns if i not in del_feature]
category = ["direction","pathclass","speedclass","LaneNum","level"]
print(datetime.datetime.now())

DNN = DNN_Model(dataset=dataset,label="label",
                use_features=use_features,
                categorical_feats=None, n_class=3)

loss = DNN[0]
acc = DNN[1]
history = DNN[2]

print("Loss on test set = ", loss)
print("Accuracy on test set = ", acc)

print(datetime.datetime.now())

plot_learning_curves(history)
# Out:
# 2020-12-14 17:47:11.670707
# Start training
#
# Train on 2866012 samples, validate on 1228292 samples
# Epoch 1/100
# 2866012/2866012 [==============================] - 28s 10us/step - loss: 0.4991 - accuracy: 0.8242 - val_loss: 0.4146 - val_accuracy: 0.8427
# Epoch 2/100
# 2866012/2866012 [==============================] - 23s 8us/step - loss: 0.4075 - accuracy: 0.8464 - val_loss: 0.4080 - val_accuracy: 0.8456
# Epoch 3/100
# 2866012/2866012 [==============================] - 22s 8us/step - loss: 0.4031 - accuracy: 0.8479 - val_loss: 0.4011 - val_accuracy: 0.8476
# Epoch 4/100
# 2866012/2866012 [==============================] - 26s 9us/step - loss: 0.4018 - accuracy: 0.8484 - val_loss: 0.4028 - val_accuracy: 0.8481
# Epoch 5/100
# 2866012/2866012 [==============================] - 25s 9us/step - loss: 0.4012 - accuracy: 0.8487 - val_loss: 0.4008 - val_accuracy: 0.8480
# Epoch 6/100
# 2866012/2866012 [==============================] - 24s 8us/step - loss: 0.4011 - accuracy: 0.8488 - val_loss: 0.3997 - val_accuracy: 0.8488
# Epoch 7/100
# 2202000/2866012 [======================>.......] - ETA: 9s - loss: 0.4010 - accuracy: 0.8488 - ETA: 11s - loss: 0.4
