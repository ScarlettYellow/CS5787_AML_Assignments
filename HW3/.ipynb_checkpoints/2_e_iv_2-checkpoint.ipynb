# %%
# %run 2_b+c_color.py
# Out:
# (900, 604, 3)
# 3
# [[[103 121  97]
#   [ 79  87  66]
#   [112 113  97]
#   ...
#   [ 85  91  79]
#   [116 117 111]
#   [ 97  93  90]]
#
#  [[110 128 102]
#   [107 115  94]
#   [100 101  85]
#   ...
#   [ 71  77  63]
#   [ 84  85  77]
#   [ 60  59  54]]]
# [[486 162]
#  [178   2]
#  [314 469]
#  [236 540]
#  [142 548]
#  [658 160]
#  [ 37 166]
#  [675 217]
#  [729 561]
#  [ 34 432]]

# %%
# use Random Forest Regressor

from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=50, max_depth=8, criterion='mse')
rfr.fit(x_train, y_train)
y_pred = rfr.predict(x_test)

print ("y_train:\n", y_train[:5])
print ("y_pred:\n", y_pred[:5])
print ("y_pred shape:", y_pred.shape)
# Out:
# y_train:
#  [[0.29803923 0.23529412 0.27450982]
#  [0.4627451  0.43137255 0.28627452]
#  [0.36078432 0.4        0.29411766]
#  [0.63529414 0.6039216  0.34901962]
#  [0.6        0.5921569  0.36078432]]
# y_pred:
#  [[0.41835587 0.22960694 0.1106351 ]
#  [0.28716896 0.28485157 0.21749911]
#  [0.11201383 0.06972614 0.14266793]
#  [0.29563597 0.17961193 0.15268968]
#  [0.45926312 0.32975298 0.1768569 ]]
# y_pred shape: (538600, 3)

# %%
# combine points and sample points

image = np.zeros_like(img)
print(image.shape)

for point, pixel in zip(sample_points, sample_point_pixels):
    image[point[0], point[1]] = pixel
for point, pixel in zip(test_points, y_pred):
    image[point[0], point[1]] = pixel
# Out:
# (900, 604, 3)

# %%
# show the final image

image = (image * 255).astype('uint8')
io.imshow(image)

# %%
# model evaluation

from sklearn import metrics

MSE = metrics.mean_squared_error(y_test, y_pred)
print('Mean Squared Error(MSE)=', MSE)
# Out:
# Mean Squared Error(MSE)= 0.005769919990926682

# %%
# pruning strategies
